# %%
#Q1
The purpose of Exception class while creating custom Exception as Exception class
provide a means to sperate the details of what to do if something happens other than the main logic of the program.

# %%
#Q2
dir(Exception)
# Out:
# ['__cause__',
#  '__class__',
#  '__context__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__suppress_context__',
#  '__traceback__',
#  'args',
#  'with_traceback']

# %%
import inspect as ipt
def tree_class(cls, ind = 0):
    print ('-' * ind, cls.__name__)
    for K in cls.__subclasses__():
        tree_class(K, ind + 3)
print ("Inbuilt exceptions is: ")
ipt.getclasstree(ipt.getmro(BaseException))
tree_class(BaseException)
# Out:
# Inbuilt exceptions is:
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# --------- PermissionError
# --------- ProcessLookupError
# --------- TimeoutError
# --------- UnsupportedOperation
# --------- itimer_error
# --------- herror
# --------- gaierror
# --------- SSLError
# ------------ SSLCertVerificationError
# ...

# %%
#Q3
#Error cause due to numeric calculations are arithmatic errors.
import logging
logging.basicConfig(filename = "12_feb_23", level = logging.ERROR)
try:
    b=0
    c=10/b
    print(c)
    logging.error("No error has been raised")
except ArithmeticError as e:
    print("dinominator cannot be zero")
    logging.error("error has been raised - {}".format(e))
# Out:
# dinominator cannot be zero

# %%
#Q4
#LookupError Exception is the Base class for errors raised when something can't be found.
try:
    dict={'key1':100,'key2':200}['key3']
    print(dict[key1])
except KeyError as e:
    print("This is keyerror")
    logging.error("key error has been raised")
except IndexError as e:
    print("this is index error")
    logging.error("index error has been raised")
# Out:
# This is keyerror

# %%
#Q5
#ImportError is generated when imported class is not created or unavailable.
#ModuleNotFoundError is generated module imported is present in a system.

import srish
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       1 #Q5
#       2 #ImportError is generated when imported class is not created or unavailable.
#       3 #ModuleNotFoundError is generated module imported is present in a system.
# ----> 5 import srish
#
# ModuleNotFoundError: No module named 'srish'

# %%
import request
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import request
#
# ModuleNotFoundError: No module named 'request'

# %%
#Q6
best practice of exception handling are:
    Always use a specific exception.
    Always print a proper message.
    Use log to store every step of error handling or log your errors.
    Avoid to write multiple exception handling.
    Document the error and clean up all the resources.
